# %%
import json

# %%
jfile='/home/jarvis/Documents/ai-ml-dl-gaze/AIML_Hmd_Database/db-050719_185335/050719_185335/ERRORS.json'

# %%
with open(jfile,'r') as f:
    data=json.load(f)

# %%
for i in data:
    total_ann += len(i['unsupported_annotation_type'])
print(total_ann)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-39-2ee594ad4590> in <module>
#       1 for i in data:
# ----> 2     total_ann += len(i['unsupported_annotation_type'])
#
# NameError: name 'total_ann' is not defined

# %%
for i in data:
    for ann in i:
        print(ann)
#     d = i['unsupported_annotation_type']
#     total_ann += len(i['unsupported_annotation_type'])
# # print(total_ann)
# Out:
# i
# m
# a
# g
# e
# s
# -
# p
# 2
# -
# 0
# 5
# 0
# 2
# 1
# 9
# _
# A
# T
# 4
# _
# v
# i
# a
# 2
# 0
# 5
# _
# 2
# 1
# 0
# 2
# 1
# 9
# i
# m
# a
# g
# e
# s
# -
# p
# 2
# -
# 0
# 5
# 0
# 2
# 1
# 9
# _
# A
# T
# 1
# _
# v
# i
# a
# 2
# 0
# 5
# _
# 2
# 1
# 0
# 3
# 1
# 9
# i
# m
# a
# g
# e
# s
# -
# p
# 1
# -
# 0
# 3
# 0
# 4
# 1
# 9
# _
# A
# T
# 4
# _
# v
# i
# a
# 2
# 0
# 5
# _
# 0
# 6
# 0
# 5
# 1
# 9
# i
# m
# a
# g
# e
# s
# -
# p
# 2
# -
# 2
# 5
# 0
# 6
# 1
# 9
# _
# A
# T
# 1
# _
# v
# i
# a
# 2
# 0
# 5
# _
# 0
# 4
# 0
# 7
# 1
# 9
# i
# m
# a
# g
# e
# s
# -
# p
# 1
# -
# 2
# 3
# 0
# 1
# 1
# 9
# _
# A
# T
# 3
# _
# v
# i
# a
# 2
# 0
# 5
# _
# 3
# 0
# 0
# 1
# 1
# 9
# i
# m
# a
# g
# e
# s
# -
# p
# 2
# -
# 0
# 5
# 0
# 2
# 1
# 9
# _
# A
# T
# 2
# _
# v
# i
# a
# 2
# 0
# 5
# _
# 0
# 3
# 0
# 4
# 1
# 9
# i
# m
# a
# g
# e
# s
# -
# p
# 3
# -
# 2
# 5
# 0
# 2
# 1
# 9
# _
# A
# T
# 5
# _
# v
# i
# a
# 2
# 0
# 5
# _
# 2
# 2
# 0
# 3
# 1
# 9
# i
# m
# a
# g
# e
# s
# -
# p
# 1
# -
# 2
# 3
# ...

# %%
if exists 'unsupported_annotation_type' in i
